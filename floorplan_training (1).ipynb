# %%
# floorplan_training.ipynb -
# !pip install -q ultralytics==8.* opencv-python-headless Pillow
from google.colab import drive
drive.mount('/content/drive')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.6 MB/s eta 0:00:00
# Mounted at /content/drive

# %%
# !mkdir -p /content/floorplan_dataset
# %cd /content/floorplan_dataset
# Out:
# /content/floorplan_dataset

# %%
EPOCHS = 400
BATCH = 8
IMGSZ = 640


# !yolo task=detect mode=train model=yolov8n.yaml data=data.yaml epochs={EPOCHS} imgsz={IMGSZ} batch={BATCH} project=/content/runs_scratch name=exp_scratch

from pathlib import Path
base_dir="/content/drive/MyDrive/Untitled folder"
Path(f"{base_dir}/output").mkdir(parents=True, exist_ok=True)
# !cp -v /content/runs_scratch/exp_scratch/weights/best.pt "{base_dir}/output/best_scratch.pt"
print("Saved:", f"{base_dir}/output/best_scratch.pt")
# Out:
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls -lh runs/detect/train/weights
# Out:
# total 12M
# -rw-r--r-- 1 root root 6.0M Nov  9 00:40 best.pt
# -rw-r--r-- 1 root root 6.0M Nov  9 00:40 last.pt
